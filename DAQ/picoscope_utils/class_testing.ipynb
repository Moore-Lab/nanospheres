# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import Picoscope_control as pc

# %%
#pico = pc.PicoScope(channels = ["A"], buffersize = 1000, sampleInterval = 1000, sampleUnit = "US", totalSamples = 1000)
#pico.Stream()
pico.stop()
pico.close()

# %%
pico.setTotalsamples(3000)
pico.Stream()

# %%
plt.plot(pico.buffersComplete[0])

# %%
# !pip install PyQt6
# Out:
# ...
#    ---------------------------------------- 0.0/6.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.5 MB 960.0 kB/s eta 0:00:07
#    - -------------------------------------- 0.2/6.5 MB 3.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/6.5 MB 3.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/6.5 MB 3.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.5 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.5 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.5 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.5 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/6.5 MB 2.4 MB/s eta 0:00:03
#    ------- -------------------------------- 1.2/6.5 MB 2.7 MB/s eta 0:00:02
# ...
