# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import Picoscope_control as pc

# %%
pico = pc.PicoScope(channels = ["A", "B"], buffersize = 1000, sampleInterval = 1000, sampleUnit = "US", totalSamples = 1000)
pico.Stream()
pico.stop()
pico.close()

# %%
pico.buffersComplete
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [ -9,  10, -28, ...,  -9,  10,  10]], dtype=int16)

# %%
plt.plot(pico.buffersComplete[0])
plt.plot(pico.buffersComplete[1])
