# %%
import importlib
import numpy as np
import labjack_utils as lu
import matplotlib.pyplot as plt

# %%
importlib.reload(lu)
# Out:
# <module 'labjack_utils' from '/Users/dcmoore/Yale University Dropbox/David Moore/uspheres/nanospheres_code/nanospheres/DAQ/LabJackT7/labjack_utils.py'>

# %%
lj = lu.LabJack()

# %%
lj.open()
ramp = np.linspace(-5, 5, 2**10)
lj.config(sample_rate=1000, num_samps_to_read=2**10, channel_list=[0,1,2],)


#lj.stream_analog_out(sample_rate=1000, writeData=ramp)
# Out:
# Opened a LabJack with Device type: 7, Connection type: 1,
# Serial number: 470037304, IP address: 0.0.0.0, Port: 0,
# Max bytes per MB: 64
# Scans per read:  1024
#
# Stream started with a scan rate of 1000 Hz.

# %%
data, totSkip = lj.read_analog_in(num_scans=10)
# Out:
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072
# got data:  3072

# %%
plt.figure()
for i in range(len(data)):
    plt.plot(data[i])

#plt.xlim(0,2000)
plt.show()

# %%
print(len(data[0]))
# Out:
# 1024

# %%
lj.close()

# %%
np.shape(data)
# Out:
# (10, 1024, 3)

# %%
totSkip
# Out:
# 0
